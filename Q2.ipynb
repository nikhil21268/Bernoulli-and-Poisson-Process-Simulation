# %% [markdown]
# (a) Simulate the density of number of arrivals until time t for λ = 5.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Define parameters
lambda_ = 5
t = 10  # Time interval

# %%
# Generate Poisson random variable
arrivals = np.random.poisson(lambda_ * t, 10000)

# %%
# Plot the histogram
plt.hist(arrivals, bins=np.arange(0, np.max(arrivals)+2)-0.5, density=True, edgecolor='black', alpha=0.7)
plt.title(f'Density of Number of Arrivals until time t for λ = {lambda_}')
plt.xlabel('Number of Arrivals')
plt.ylabel('Density')
plt.show()

# %%
# Calculate the mean value
mean_arrivals = np.mean(arrivals)
print(f'Mean number of arrivals: {mean_arrivals}')
# Out:
# Mean number of arrivals: 49.9755

# %% [markdown]
# This code simulates the density of the number of arrivals in the time interval (0, t] for a Poisson process with λ = 5. It generates 10,000 samples and plots a histogram showing the density. The mean number of arrivals is calculated and printed.
#
# The mean comes out to be, λ * t = 50 (approximately).
#
# Here, t <- time interval (viz. 10 in my implementation - can be adjusted in the code, as per requirement)

# %%
# Define parameters
lambda_ = 5
t = 100  # Time interval

# Generate Poisson random variable
arrivals = np.random.poisson(lambda_ * t, 10000)
# Plot the histogram
plt.hist(arrivals, bins=np.arange(0, np.max(arrivals)+2)-0.5, density=True, edgecolor='black', alpha=0.7)
plt.title(f'Density of Number of Arrivals until time t for λ = {lambda_}')
plt.xlabel('Number of Arrivals')
plt.ylabel('Density')
plt.show()
# Calculate the mean value
mean_arrivals = np.mean(arrivals)
print(f'Mean number of arrivals: {mean_arrivals}')
# Out:
# Mean number of arrivals: 500.074

# %% [markdown]
# This code simulates the density of the number of arrivals in the time interval (0, t] for a Poisson process with λ = 5. It generates 10,000 samples and plots a histogram showing the density. The mean number of arrivals is calculated and printed.
#
# The mean comes out to be, λ * t = 500 (approximately).
#
# Here, t <- time interval (viz. 100 in my implementation - can be adjusted in the code, as per requirement)

# %% [markdown]
# (b) Simulate the density of number of arrivals until time t for λ = 15.

# %%
# Define parameters for part (b)
lambda_15 = 15
t = 10

# %%
# Generate Poisson random variable for λ = 15
arrivals_15 = np.random.poisson(lambda_15 * t, 10000)

# %%
# Plot the histogram
plt.hist(arrivals_15, bins=np.arange(0, np.max(arrivals_15)+2)-0.5, density=True, edgecolor='black', alpha=0.7)
plt.title(f'Density of Number of Arrivals until time t for λ = {lambda_15}')
plt.xlabel('Number of Arrivals')
plt.ylabel('Density')
plt.show()

# %%
# Calculate the mean value
mean_arrivals_15 = np.mean(arrivals_15)
print(f'Mean number of arrivals: {mean_arrivals_15}')
# Out:
# Mean number of arrivals: 150.0133

# %% [markdown]
# This code does the same as part (a) but for λ = 15, & t = 10.

# %%
# Define parameters for part (b)
lambda_15 = 15
# Generate Poisson random variable for λ = 15
t = 100
arrivals_15 = np.random.poisson(lambda_15 * t, 10000)
# Plot the histogram
plt.hist(arrivals_15, bins=np.arange(0, np.max(arrivals_15)+2)-0.5, density=True, edgecolor='black', alpha=0.7)
plt.title(f'Density of Number of Arrivals until time t for λ = {lambda_15}')
plt.xlabel('Number of Arrivals')
plt.ylabel('Density')
plt.show()
# Calculate the mean value
mean_arrivals_15 = np.mean(arrivals_15)
print(f'Mean number of arrivals: {mean_arrivals_15}')
# Out:
# Mean number of arrivals: 1499.6626

# %% [markdown]
# (c) Simulate the first inter-arrival time of the process.

# %%
# Generate the first inter-arrival time
inter_arrival_time = np.random.exponential(scale=1/lambda_, size=10000)

# %%
# Plot the histogram
plt.hist(inter_arrival_time, bins=30, density=True, edgecolor='black', alpha=0.7)
plt.title('Density of First Inter-Arrival Time')
plt.xlabel('Inter-Arrival Time')
plt.ylabel('Density')
plt.show()

# %% [markdown]
# This code simulates the first inter-arrival time of the process using an exponential distribution with parameter λ = 5. It generates 10,000 samples and plots a histogram showing the density.

# %% [markdown]
# Now, the below code does the exact same thing as part (c), except that it uses 'num_simulations' as a parameter too.
#
# This plots 1000 simulations of the exponential RV on the graph, & the result is that, the graph appears more smoother, & the differences for each simulation is clearly visible.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define parameters
lambda_ = 5  # Arrival rate

# Define the number of simulations
num_simulations = 1000

# Generate inter-arrival times for each simulation
inter_arrival_times = np.random.exponential(scale=1/lambda_, size=(num_simulations, 10000))

# Plot histograms for each simulation
for i in range(num_simulations):
    plt.hist(inter_arrival_times[i], bins=30, density=True, alpha=0.5)

plt.title('Density of First Inter-Arrival Time')
plt.xlabel('Inter-Arrival Time')
plt.ylabel('Density')
plt.show()
