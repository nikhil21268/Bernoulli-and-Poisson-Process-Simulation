# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Define parameters
num_simulations = 1000
num_trials = 20

# %%
# (a) Simulation for p = 0.8
p_a = 0.8
results_a = np.random.binomial(num_trials, p_a, num_simulations)

# %%
# (b) Simulation for p = 0.5
p_b = 0.5
results_b = np.random.binomial(num_trials, p_b, num_simulations)

# %%
# Plot histograms
plt.figure(figsize=(12, 6))

# %%
plt.subplot(1, 2, 1)
plt.hist(results_a, bins=np.arange(0, num_trials+2)-0.5, edgecolor='black', alpha=0.7)
plt.title(f'Simulation for p = {p_a}, for the Binomial RV')
plt.xlabel('# of Heads Occured, i.e. Success')
plt.ylabel('Frequency of the # of Heads')
# Out:
# Text(0, 0.5, 'Frequency of the # of Heads')

# %%
plt.subplot(1, 2, 2)
plt.hist(results_b, bins=np.arange(0, num_trials+2)-0.5, edgecolor='black', alpha=0.7)
plt.title(f'Simulation for p = {p_b}, for the Binomial RV')
plt.xlabel('# of Heads Occured, i.e. Success')
plt.ylabel('Frequency of the # of Heads')
# Out:
# Text(0, 0.5, 'Frequency of the # of Heads')

# %%
plt.tight_layout()
plt.show()

# %% [markdown]
# The Bernoulli process with p=0.8 means that we have a higher probability of success in each trial.
#
# This implies that we expect more "heads" when a coin is tossed.
#
# In 1000 simulations of tossing the coin 20 times each, we would expect to see more successes.

# %% [markdown]
# For p=0.5, the probability of success (getting "heads") is exactly 50%, which is equivalent to a fair coin toss.
#
# In 1000 simulations, we would expect an equal number of "heads" and "tails" on average.

# %% [markdown]
# Therefore, for part (a), where p = 0.8, you will see a histogram with more successes on average compared to part (b), where p = 0.5.
#
# This is because a higher value of p leads to a higher probability of success in each trial.

# %% [markdown]
# Inference -

# %% [markdown]
# The average number of heads, based on performing the experiment 1000 times, correponds to n * p, where,
#
# n <- # of coin tosses (viz. 20 in our case, as per the question)
#
# p <- Probability of success (viz. getting a head in our case, as per question)
#
# This follows from the fact that # of bernoulli success, being a RV, follows a binomial distribution, & has an expected value = n * p.

# %% [markdown]
# Therefore, for part (a),
#
# the average # of heads = 0.8 * 20 = 16 (can be inferred as an approximation, from the plot)
#
# & for part (b),
#
# the average # of heads = 0.5 * 20 = 10 (can be inferred as an approximation, from the plot)
